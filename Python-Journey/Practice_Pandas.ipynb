# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(r'/Users/pranavaditya/Desktop/Data-Engineering-Journey/Python-Journey/movies.csv')
df.head(5)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 df = pd.read_csv(r'/Users/pranavaditya/Desktop/Data-Engineering-Journey/Python-Journey/movies.csv')
#       2 df.head(5)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/io/parsers/readers.py:873, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, skip_blank_lines, parse_dates, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
df.sample(4)
# Out:
#                                  title   industry  release_year  imdb_rating  \
# 6                         Interstellar  Hollywood          2014          8.6
# 17                   Avengers: Endgame  Hollywood          2019          8.4
# 19  Captain America: The First Avenger  Hollywood          2011          6.9
# 12                       The Godfather  Hollywood          1972          9.2
#
#                    studio  budget  revenue      unit currency language
# 6   Warner Bros. Pictures   165.0    701.8  Millions      USD  English
# 17         Marvel Studios   400.0   2798.0  Millions      USD  English
# 19         Marvel Studios   216.7    370.6  Millions      USD  English
# 12     Paramount Pictures     7.2    291.0  Millions      USD  English

# %%
print(df['imdb_rating'].mean())
# Out:
# 7.919444444444445

# %%
df[]

# %%
df.imdb_rating.min()
# Out:
# 1.9

# %%
df.imdb_rating.mean()
# Out:
# 7.919444444444445

# %%
dir(df.imdb_rating)
# Out:
# ['T',
#  '_AXIS_LEN',
#  '_AXIS_ORDERS',
#  '_AXIS_TO_AXIS_NUMBER',
#  '_HANDLED_TYPES',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__annotations__',
#  '__array__',
#  '__array_priority__',
#  '__array_ufunc__',
#  '__arrow_c_stream__',
#  '__bool__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__matmul__',
#  '__mod__',
#  '__module__',
#  '__mul__',
#  '__ne__',
#  '__neg__',
#  '__new__',
#  '__or__',
# ...

# %%
df_b = df[df['industry']=='Hollywood']
df_h = df[df['industry']=='Bollywood']
df_h.imdb_rating.mean()
# Out:
# 7.656250000000001

# %%
df['industry'].unique()
# Out:
# <StringArray>
# ['Bollywood', 'Hollywood']
# Length: 2, dtype: str

# %%
df.industry.value_counts()
# Out:
# industry
# Hollywood    20
# Bollywood    17
# Name: count, dtype: int64

# %%
df.language.value_counts()
# Out:
# language
# English    20
# Hindi      12
# Telugu      3
# Bengali     1
# Kannada     1
# Name: count, dtype: int64

# %%
df.groupby('language')['title'].count()
# Out:
# language
# Bengali     1
# English    20
# Hindi      12
# Kannada     1
# Telugu      3
# Name: title, dtype: int64

# %%
df_new=df[['title','industry','language']]
df_new
# Out:
#                                           title   industry language
# 0                               Pather Panchali  Bollywood  Bengali
# 1   Doctor Strange in the Multiverse of Madness  Hollywood  English
# 2                         Thor: The Dark World   Hollywood  English
# 3                               Thor: Ragnarok   Hollywood  English
# 4                       Thor: Love and Thunder   Hollywood  English
# 5                      The Shawshank Redemption  Hollywood  English
# 6                                  Interstellar  Hollywood  English
# 7                      The Pursuit of Happyness  Hollywood  English
# 8                                     Gladiator  Hollywood  English
# 9                                       Titanic  Hollywood  English
# 10                        It's a Wonderful Life  Hollywood  English
# 11                                       Avatar  Hollywood  English
# 12                                The Godfather  Hollywood  English
# ...

# %%
df[(df.release_year>=2000) and (df.release_year<=2010)]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 df[(df.release_year>=2000) and (df.release_year<=2010)]
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/generic.py:1513, in NDFrame.__bool__(self)
#    1511     @final
#    1512     def __bool__(self) -> NoReturn:
# -> 1513         raise ValueError(
#    1514             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1515             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#    1516         )
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
df[df.studio == 'Marvel Studios']
# Out:
#                                           title   industry  release_year  \
# 1   Doctor Strange in the Multiverse of Madness  Hollywood          2022
# 2                         Thor: The Dark World   Hollywood          2013
# 3                               Thor: Ragnarok   Hollywood          2017
# 4                       Thor: Love and Thunder   Hollywood          2022
# 17                            Avengers: Endgame  Hollywood          2019
# 18                       Avengers: Infinity War  Hollywood          2018
# 19           Captain America: The First Avenger  Hollywood          2011
# 20          Captain America: The Winter Soldier  Hollywood          2014
#
#     imdb_rating          studio  budget  revenue      unit currency language
# 1           7.0  Marvel Studios   200.0    954.8  Millions      USD  English
# 2           6.8  Marvel Studios   165.0    644.8  Millions      USD  English
# 3           7.9  Marvel Studios   180.0    854.0  Millions      USD  English
# ...

# %%
df.describe()
# Out:
#        release_year  imdb_rating        budget        revenue
# count     37.000000    36.000000     37.000000      37.000000
# mean    2007.027027     7.919444   2084.975135    4117.135135
# std       17.657995     1.204947  11477.487145   16372.462682
# min     1946.000000     1.900000      1.000000       3.100000
# 25%     2001.000000     7.800000     15.500000     263.100000
# 50%     2014.000000     8.100000    165.000000     701.800000
# 75%     2018.000000     8.400000    250.000000    2000.000000
# max     2022.000000     9.300000  70000.000000  100000.000000

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 37 entries, 0 to 36
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   title         37 non-null     str
#  1   industry      37 non-null     str
#  2   release_year  37 non-null     int64
#  3   imdb_rating   36 non-null     float64
#  4   studio        34 non-null     str
#  5   budget        37 non-null     float64
#  6   revenue       37 non-null     float64
#  7   unit          37 non-null     str
#  8   currency      37 non-null     str
#  9   language      37 non-null     str
# dtypes: float64(3), int64(1), str(6)
# memory usage: 3.0 KB

# %%
df[(df.imdb_rating==df['imdb_rating'].max()) |(df.imdb_rating==df['imdb_rating'].min())  ]['title']
# Out:
# 5     The Shawshank Redemption
# 31                      Race 3
# Name: title, dtype: str

# %%
df['age']=df['release_year'].apply(lambda x : 2026-x)
df
# Out:
#                                           title   industry  release_year  \
# 0                               Pather Panchali  Bollywood          1955
# 1   Doctor Strange in the Multiverse of Madness  Hollywood          2022
# 2                         Thor: The Dark World   Hollywood          2013
# 3                               Thor: Ragnarok   Hollywood          2017
# 4                       Thor: Love and Thunder   Hollywood          2022
# 5                      The Shawshank Redemption  Hollywood          1994
# 6                                  Interstellar  Hollywood          2014
# 7                      The Pursuit of Happyness  Hollywood          2006
# 8                                     Gladiator  Hollywood          2000
# 9                                       Titanic  Hollywood          1997
# 10                        It's a Wonderful Life  Hollywood          1946
# 11                                       Avatar  Hollywood          2009
# ...

# %%
df['profit'] = df['revenue']-df['budget']
df
# Out:
#                                           title   industry  release_year  \
# 0                               Pather Panchali  Bollywood          1955
# 1   Doctor Strange in the Multiverse of Madness  Hollywood          2022
# 2                         Thor: The Dark World   Hollywood          2013
# 3                               Thor: Ragnarok   Hollywood          2017
# 4                       Thor: Love and Thunder   Hollywood          2022
# 5                      The Shawshank Redemption  Hollywood          1994
# 6                                  Interstellar  Hollywood          2014
# 7                      The Pursuit of Happyness  Hollywood          2006
# 8                                     Gladiator  Hollywood          2000
# 9                                       Titanic  Hollywood          1997
# 10                        It's a Wonderful Life  Hollywood          1946
# 11                                       Avatar  Hollywood          2009
# ...

# %%
df.index
# Out:
# RangeIndex(start=0, stop=37, step=1)

# %%
df.set_index('title',inplace = True)

# %%
df.head(10)
# Out:
#                                               industry  release_year  \
# title
# Pather Panchali                              Bollywood          1955
# Doctor Strange in the Multiverse of Madness  Hollywood          2022
# Thor: The Dark World                         Hollywood          2013
# Thor: Ragnarok                               Hollywood          2017
# Thor: Love and Thunder                       Hollywood          2022
# The Shawshank Redemption                     Hollywood          1994
# Interstellar                                 Hollywood          2014
# The Pursuit of Happyness                     Hollywood          2006
# Gladiator                                    Hollywood          2000
# Titanic                                      Hollywood          1997
#
#                                              imdb_rating  \
# title
# Pather Panchali                                      8.3
# Doctor Strange in the Multiverse of Madness          7.0
# ...

# %%
df.reset_index(inplace = True)
df
# Out:
#     index                                        title   industry  \
# 0       0                              Pather Panchali  Bollywood
# 1       1  Doctor Strange in the Multiverse of Madness  Hollywood
# 2       2                        Thor: The Dark World   Hollywood
# 3       3                              Thor: Ragnarok   Hollywood
# 4       4                      Thor: Love and Thunder   Hollywood
# 5       5                     The Shawshank Redemption  Hollywood
# 6       6                                 Interstellar  Hollywood
# 7       7                     The Pursuit of Happyness  Hollywood
# 8       8                                    Gladiator  Hollywood
# 9       9                                      Titanic  Hollywood
# 10     10                        It's a Wonderful Life  Hollywood
# 11     11                                       Avatar  Hollywood
# 12     12                                The Godfather  Hollywood
# ...

# %%
df2 = pd.read_csv('stock_data.csv',skiprows=1,na_values = {
    'eps':['not available']
})
df2
# Out:
#   tickers    eps  revenue price         people
# 0   GOOGL  27.82       87   845     larry page
# 1     WMT   4.61      484    65           n.a.
# 2    MSFT  -1.00       85    64     bill gates
# 3    RIL     NaN       50  1023  mukesh ambani
# 4    TATA   5.60       -1  n.a.     ratan tata

# %%
df2.to_csv('kucbhi.csv',index = False)

# %%
def standardize(curr):
    if (curr == '$$' or curr == 'Dollars'):
        return 'USD'
    return curr
df_financials = pd.read_csv(r'/Users/pranavaditya/Desktop/Data-Engineering-Journey/Python-Journey/movies.csv',converters={
    'currency':standardize
})
df_financials
# Out:
#                                           title   industry  release_year  \
# 0                               Pather Panchali  Bollywood          1955
# 1   Doctor Strange in the Multiverse of Madness  Hollywood          2022
# 2                         Thor: The Dark World   Hollywood          2013
# 3                               Thor: Ragnarok   Hollywood          2017
# 4                       Thor: Love and Thunder   Hollywood          2022
# 5                      The Shawshank Redemption  Hollywood          1994
# 6                                  Interstellar  Hollywood          2014
# 7                      The Pursuit of Happyness  Hollywood          2006
# 8                                     Gladiator  Hollywood          2000
# 9                                       Titanic  Hollywood          1997
# 10                        It's a Wonderful Life  Hollywood          1946
# 11                                       Avatar  Hollywood          2009
# ...

# %%
df3 = pd.read_csv('/Users/pranavaditya/Desktop/Data-Engineering-Journey/weather_by_cities.csv',parse_dates = ['day'])
df3
# Out:
#           day      city  temperature  windspeed   event
# 0  2017-01-01  new york           32          6    Rain
# 1  2017-01-02  new york           36          7   Sunny
# 2  2017-01-03  new york           28         12    Snow
# 3  2017-01-04  new york           33          7   Sunny
# 4  2017-01-01    mumbai           90          5   Sunny
# 5  2017-01-02    mumbai           85         12     Fog
# 6  2017-01-03    mumbai           87         15     Fog
# 7  2017-01-04    mumbai           92          5    Rain
# 8  2017-01-01     paris           45         20   Sunny
# 9  2017-01-02     paris           50         13  Cloudy
# 10 2017-01-03     paris           54          8  Cloudy
# 11 2017-01-04     paris           42         10  Cloudy

# %%
type(df3.day[0])
# Out:
# pandas.Timestamp

# %%
df3.ffill()
# Out:
#           day      city  temperature  windspeed   event
# 0  2017-01-01  new york           32          6    Rain
# 1  2017-01-02  new york           36          7   Sunny
# 2  2017-01-03  new york           28         12    Snow
# 3  2017-01-04  new york           33          7   Sunny
# 4  2017-01-01    mumbai           90          5   Sunny
# 5  2017-01-02    mumbai           85         12     Fog
# 6  2017-01-03    mumbai           87         15     Fog
# 7  2017-01-04    mumbai           92          5    Rain
# 8  2017-01-01     paris           45         20   Sunny
# 9  2017-01-02     paris           50         13  Cloudy
# 10 2017-01-03     paris           54          8  Cloudy
# 11 2017-01-04     paris           42         10  Cloudy

# %%
df3.bfill()
# Out:
#           day      city  temperature  windspeed   event
# 0  2017-01-01  new york           32          6    Rain
# 1  2017-01-02  new york           36          7   Sunny
# 2  2017-01-03  new york           28         12    Snow
# 3  2017-01-04  new york           33          7   Sunny
# 4  2017-01-01    mumbai           90          5   Sunny
# 5  2017-01-02    mumbai           85         12     Fog
# 6  2017-01-03    mumbai           87         15     Fog
# 7  2017-01-04    mumbai           92          5    Rain
# 8  2017-01-01     paris           45         20   Sunny
# 9  2017-01-02     paris           50         13  Cloudy
# 10 2017-01-03     paris           54          8  Cloudy
# 11 2017-01-04     paris           42         10  Cloudy

# %%
df3.select_dtypes(include='number').interpolate()
# Out:
#     temperature  windspeed
# 0            32          6
# 1            36          7
# 2            28         12
# 3            33          7
# 4            90          5
# 5            85         12
# 6            87         15
# 7            92          5
# 8            45         20
# 9            50         13
# 10           54          8
# 11           42         10

# %%
df3.dtypes
# Out:
# day            datetime64[us]
# city                      str
# temperature             int64
# windspeed               int64
# event                     str
# dtype: object

# %%
df3
# Out:
#           day      city  temperature  windspeed   event
# 0  2017-01-01  new york           32          6    Rain
# 1  2017-01-02  new york           36          7   Sunny
# 2  2017-01-03  new york           28         12    Snow
# 3  2017-01-04  new york           33          7   Sunny
# 4  2017-01-01    mumbai           90          5   Sunny
# 5  2017-01-02    mumbai           85         12     Fog
# 6  2017-01-03    mumbai           87         15     Fog
# 7  2017-01-04    mumbai           92          5    Rain
# 8  2017-01-01     paris           45         20   Sunny
# 9  2017-01-02     paris           50         13  Cloudy
# 10 2017-01-03     paris           54          8  Cloudy
# 11 2017-01-04     paris           42         10  Cloudy

# %%
g = df3.groupby('city')
g

# %%
for city ,data in g:
    print(city)
    print("Data:",data.temperature.max())
# Out:
# mumbai
# Data: 92
# new york
# Data: 36
# paris
# Data: 54

# %%
g.min()
# Out:
#                 day  temperature  windspeed   event
# city
# mumbai   2017-01-01           85          5     Fog
# new york 2017-01-01           28          6    Rain
# paris    2017-01-01           42          8  Cloudy

# %%
g.describe()
# Out:
#            day                                                                 \
#          count                 mean                  min                  25%
# city
# mumbai       4  2017-01-02 12:00:00  2017-01-01 00:00:00  2017-01-01 18:00:00
# new york     4  2017-01-02 12:00:00  2017-01-01 00:00:00  2017-01-01 18:00:00
# paris        4  2017-01-02 12:00:00  2017-01-01 00:00:00  2017-01-01 18:00:00
#
#                                                                               \
#                           50%                  75%                  max  std
# city
# mumbai    2017-01-02 12:00:00  2017-01-03 06:00:00  2017-01-04 00:00:00  NaN
# new york  2017-01-02 12:00:00  2017-01-03 06:00:00  2017-01-04 00:00:00  NaN
# paris     2017-01-02 12:00:00  2017-01-03 06:00:00  2017-01-04 00:00:00  NaN
#
#          temperature         ...                 windspeed                    \
#                count   mean  ...   max       std     count   mean  min   25%
# ...

# %%
g.size()
# Out:
# city
# mumbai      4
# new york    4
# paris       4
# dtype: int64

# %%
g = df3.groupby()

# %%
def grouper(x):
    if(80<=x<=90):
        return '80-90'
    elif(50<=x<=60):
        return '50-60'
    else:
        return 'others'

# %%
df3['range']=df3['temperature'].apply(grouper)

# %%
df3
# Out:
#           day      city  temperature  windspeed   event   range
# 0  2017-01-01  new york           32          6    Rain  others
# 1  2017-01-02  new york           36          7   Sunny  others
# 2  2017-01-03  new york           28         12    Snow  others
# 3  2017-01-04  new york           33          7   Sunny  others
# 4  2017-01-01    mumbai           90          5   Sunny   80-90
# 5  2017-01-02    mumbai           85         12     Fog   80-90
# 6  2017-01-03    mumbai           87         15     Fog   80-90
# 7  2017-01-04    mumbai           92          5    Rain  others
# 8  2017-01-01     paris           45         20   Sunny  others
# 9  2017-01-02     paris           50         13  Cloudy   50-60
# 10 2017-01-03     paris           54          8  Cloudy   50-60
# 11 2017-01-04     paris           42         10  Cloudy  others

# %%
g1=df3.groupby('range')

# %%
for key,data in g1:
    print(key)
    print(data)
# Out:
# 50-60
#           day   city  temperature  windspeed   event  range
# 9  2017-01-02  paris           50         13  Cloudy  50-60
# 10 2017-01-03  paris           54          8  Cloudy  50-60
# 80-90
#          day    city  temperature  windspeed  event  range
# 4 2017-01-01  mumbai           90          5  Sunny  80-90
# 5 2017-01-02  mumbai           85         12    Fog  80-90
# 6 2017-01-03  mumbai           87         15    Fog  80-90
# others
#           day      city  temperature  windspeed   event   range
# 0  2017-01-01  new york           32          6    Rain  others
# 1  2017-01-02  new york           36          7   Sunny  others
# 2  2017-01-03  new york           28         12    Snow  others
# 3  2017-01-04  new york           33          7   Sunny  others
# 7  2017-01-04    mumbai           92          5    Rain  others
# 8  2017-01-01     paris           45         20   Sunny  others
# 11 2017-01-04     paris           42         10  Cloudy  others
