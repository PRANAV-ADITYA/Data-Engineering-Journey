# %%
import logging

# %%
# Configure the basic logging settings
logging.basicConfig(level = logging.DEBUG,
                    filename='app.log',
                     filemode = 'w',
                     format = '%(asctime)s - %(name)s - %(levelname)s - %(message)s',
                       force = True)

# log messages with different severity levels 
logging.debug("This is a debug message")
logging.info("This is a info message")
logging.warning("This is a warning message")
logging.error("This is a error message")
logging.critical("This is an error message")

# %%
print(logging.getLogger().level)
# Out:
# 10

# %% [markdown]
# # Loggin with multiple loggers(For different parts of the application
# )

# %%
# Create a logger
logger1  = logging.getLogger("Module 1")
logger1.setLevel(logging.DEBUG)

logger2 = logging.getLogger("Module 2")
logger2.setLevel(logging.WARNING)

# %%
logger1.debug("This is a debug message for module 1")
logger2.warning("This is a warning message for module 2")

# %%
# !pip install pytest
# Out:
# Collecting pytest
#   Downloading pytest-9.1.1-py3-none-any.whl.metadata (7.6 kB)
# Collecting iniconfig>=1.0.1 (from pytest)
#   Downloading iniconfig-2.3.0-py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: packaging>=22 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pytest) (24.2)
# Collecting pluggy<2,>=1.5 (from pytest)
#   Downloading pluggy-1.6.0-py3-none-any.whl.metadata (4.8 kB)
# Requirement already satisfied: pygments>=2.7.2 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pytest) (2.18.0)
# Downloading pytest-9.1.1-py3-none-any.whl (386 kB)
# Downloading iniconfig-2.3.0-py3-none-any.whl (7.5 kB)
# Downloading pluggy-1.6.0-py3-none-any.whl (20 kB)
# Installing collected packages: pluggy, iniconfig, pytest
# Successfully installed iniconfig-2.3.0 pluggy-1.6.0 pytest-9.1.1
#
# [notice] A new release of pip is available: 25.0.1 -> 26.1.2
# [notice] To update, run: pip install --upgrade pip

# %%
# !pip install mysql-connector-python
# Out:
# Requirement already satisfied: mysql-connector-python in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (8.4.0)
#
# [notice] A new release of pip is available: 25.0.1 -> 26.1.2
# [notice] To update, run: pip install --upgrade pip
